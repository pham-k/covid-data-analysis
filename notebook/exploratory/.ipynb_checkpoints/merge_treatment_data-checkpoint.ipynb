# %%
import pandas as pd
import pathlib

# %%
src = pathlib.Path().cwd().parent.parent / 'data' / 'external' / 'treatment-data'
current_date = '2021-08-19'
column_name = [
    'level',
    'no',
    'hospital',
    'no_bed',
    'no_positive',
    'no_positive_treating',
    'no_positive_children',
    'no_positive_pregnant',
    'no_positive_else',
    'no_positive_cs',
    'no_mild_not_comorbidity',
    'no_mild_stable_comorbidity',
    'no_in',
    'no_up',
    'no_down',
    'no_out',
    'no_out_cs',
    'no_death',
    'no_death_cs',
    'no_death_other_causes',
    'no_test_tomorrow',
    'no_ecmo_total',
    'no_ecmo_in_use',
    'no_dialysis_total',
    'no_dialysis_in_use',
    'no_ivent_total',
    'no_ivent_in_use',
    'no_hfnc_total',
    'no_hfnc_in_use',
    'no_cpap_total',
    'no_cpap_in_use',
    'no_bipap_total',
    'no_bipap_in_use',
    'no_mask_total',
    'no_mask_in_use',
    'no_oxy_total',
    'no_oxy_in_use'
]

# %%
df = pd.read_excel(
    src / (current_date + '.xlsx'),
    skiprows=3,
    header=0
)
df.columns = column_name
df['date_report'] = pd.to_datetime(current_date)

# %%
df.tail(10)
df_summary = df.iloc[-5:,:]
df_1 = df.iloc[:-5,:]

# %%
df_summary
# df_1.tail()
# Out:
#     level  no                       hospital  no_bed  no_positive  \
# 99    NaN NaN                     TỔNG CỘNG:   59596        41193
# 100   NaN NaN                  Tổng Tầng 2 :   55507        38025
# 101   NaN NaN                  Tổng Tầng 3 :    4089         3168
# 102   NaN NaN  Tỉ lệ phần trăm theo Tầng 2 :      93           92
# 103   NaN NaN  Tỉ lệ phần trăm theo Tầng 3 :       6            7
#
#      no_positive_treating  no_positive_children  no_positive_pregnant  \
# 99                  38174                  3459                   345
# 100                 35067                  3442                   336
# 101                  3107                    17                     9
# 102                    99                    97                    91
# 103                     0                     2                     8
#
#      no_positive_else  no_positive_cs  ...  no_hfnc_in_use  no_cpap_total  \
# 99              34370          220652  ...            1286            228
# 100             31289          209516  ...             821            190
# 101              3081           11136  ...             465             38
# 102                91              94  ...              63             83
# 103                 8               5  ...              36             16
#
#      no_cpap_in_use  no_bipap_total  no_bipap_in_use  no_mask_total  \
# 99               91              98               24           9094
# 100              73              86               22           7334
# 101              18              12                2           1760
# 102              80              87               91             80
# 103              19              12                8             19
#
#      no_mask_in_use  no_oxy_total  no_oxy_in_use  date_report
# 99             5111         13232           7890   2021-09-19
# 100            4050          9883           5734   2021-09-19
# 101            1061          3349           2156   2021-09-19
# 102              79            74             72   2021-09-19
# 103              20            25             27   2021-09-19
#
# [5 rows x 38 columns]
