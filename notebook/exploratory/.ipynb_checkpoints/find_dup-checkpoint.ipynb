# %%
import pandas as pd
import pathlib

# %%
interim = pathlib.Path().cwd().parent.parent / 'data' / 'interim'

# %%
df = pd.read_csv(interim / 'public.csv')
# pbdf = pd.read_csv(interim / 'pbdf.csv')

# %%
# shdf.info()
# shdf.head()

# %%
# show dup by name_full, yob and date_positive for further cleaning
df[df.duplicated(subset=['date_positive','name_full', 'yob'], keep=False)].sort_values('date_positive')
# Out:
#                name_full  sex   yob addr_dist_home date_report date_positive
# 1014    NGUYỄN HOÀNG DUY  NAM  1993           QHMN  17/06/2021    16/06/2021
# 1088    NGUYỄN HOÀNG DUY  NAM  1993           QBTN  18/06/2021    16/06/2021
# 1198      NGUYỄN THỊ NGA   NỮ  1963           QA01  19/06/2021    18/06/2021
# 2644      NGUYỄN THỊ NGA   NỮ  1963           QA01  25/06/2021    18/06/2021
# 1614     NGUYỄN PHÚ ĐÔNG  NAM  1994           QBTN  21/06/2021    21/06/2021
# 2657     NGUYỄN PHÚ ĐÔNG  NAM  1994           QBTN  25/06/2021    21/06/2021
# 1966     TRƯƠNG NGỌC LAN   NỮ  1964           QBCH  24/06/2021    22/06/2021
# 2742     TRƯƠNG NGỌC LAN   NỮ  1964           QBCH  25/06/2021    22/06/2021
# 3511   HUỲNH THỊ BÉ MINH  NAM  1995           QBCH  27/06/2021    26/06/2021
# 3517   HUỲNH THỊ BÉ MINH   NỮ  1995           QBCH  27/06/2021    26/06/2021
# 468       MAI THANH TÙNG  NaN  1962           QA01  13/06/2021           NaN
# 489       MAI THANH TÙNG  NAM  1962           QA01  14/06/2021           NaN
# 3123        ĐẶNG THỊ HẢI   NỮ  1980           QGVP  26/06/2021           NaN
# 3124  PHẠM VĂN CÔNG MINH  NAM  2008           QGVP  26/06/2021           NaN
# 3930        ĐẶNG THỊ HẢI   NỮ  1980           QGVP  29/06/2021           NaN
# 3931  PHẠM VĂN CÔNG MINH  NAM  2008           QGVP  29/06/2021           NaN

# %%
# pbdf[pbdf.duplicated(subset=['date_positive','name_full', 'yob'], keep=False)].sort_values('date_positive')
