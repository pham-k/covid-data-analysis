# %%
import pandas as pd
import pathlib
import numpy as np

# %%
src = pathlib.Path().cwd().parent.parent / 'data' / 'interim'
ref = pathlib.Path().cwd().parent.parent / 'reference'

# %%
df = pd.read_csv(src / 'test-data.csv')

# %%
# df
# df[df.reason.str.contains('TEST NHANH')]
# df[df.diag_proc.isna()]
# df[
#     df.reason.str.contains('TEST NHANH')
#     & df.result.str.contains('DUONG TINH')
# ]
# df[df.result.str.contains('DUONG TINH')]
# df[df.result == 'DUONG TINH']
# Out:
#                     id date_sample  sex     yob  \
# 168      U07T222112327  2021-06-03  NAM  2000.0
# 187      U07T222112325  2021-06-03  NAM  1983.0
# 277      U07T212107571  2021-06-03  NAM  1989.0
# 388       U07T11211747  2021-06-03  NAM  1999.0
# 2169     U07T222113349  2021-06-03  NAM  1993.0
# ...                ...         ...  ...     ...
# 2038785  U07Z522100997  2021-09-13   NU  1993.0
# 2038787  U07Z522100999  2021-09-13  NAM  2017.0
# 2038796  U07Z522101111  2021-09-13  NAM  1983.0
# 2038797  U07Z522101112  2021-09-13   NU  2015.0
# 2038802  U07Z522101117  2021-09-13   NU  2021.0
#
#                                                     reason      result  \
# 168                                                    NAN  DUONG TINH
# 187                                                    NAN  DUONG TINH
# 277                                DOI TUONG DIEU TRA DICH  DUONG TINH
# 388                                DOI TUONG DIEU TRA DICH  DUONG TINH
# ...
