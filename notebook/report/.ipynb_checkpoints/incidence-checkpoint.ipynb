# %%
import pandas as pd
import matplotlib.pyplot as plt
import pathlib
import numpy as np
import math

# %%
interim = pathlib.Path().cwd().parent.parent / 'data' / 'interim'

# %%
inc = pd.read_csv(interim / 'inc.csv', index_col=0)
inc_sex = pd.read_csv(interim / 'inc_sex.csv', index_col=0)
inc_adult = pd.read_csv(interim / 'inc_adult.csv', index_col=0)
inc_ag = pd.read_csv(interim / 'inc_ag.csv', index_col=0)
inc_adh_cumsum = pd.read_csv(interim / 'inc_adh_cumsum.csv', index_col=0)
inc_adh_rollmean = pd.read_csv(interim / 'inc_adh_rollmean.csv', index_col=0)
inc_adh_rollsum = pd.read_csv(interim / 'inc_adh_rollsum.csv', index_col=0)

# %%
inc_adh_rollmean.date_report = pd.to_datetime(inc_adh_rollmean.date_report)

# %%
# inc_adh_rollmean[inc_adh_rollmean.addr_dist_home == 'QA01']
# inc_adh_rollmean.info()
# inc_adh_cumsum[inc_adh_cumsum.addr_dist_home == 'QA08']
# inc.tail()

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i] + 600, y[i], ha='center', va='top', rotation=90)
        
fig, ax = plt.subplots(figsize=(16,8))

# [bar] So ca moi theo ngay
ax.bar(inc.index, inc.case, label='Số ca mới theo ngày', linewidth=3, alpha=0.5, color='gray')
# [line] BDTB so ca moi theo ngay
ax.plot(inc.index, inc.case_rm, label='Biến động trung bình 7 ngày', linewidth=3, color='black')

# [bar] So ca moi theo sex: male
# ax.bar(inc_sex.index, inc_sex.male, label='Nam', color='blue', alpha=0.4)
# [bar] So ca moi theo sex: female
# ax.bar(inc_sex.index, inc_sex.female, bottom=inc_sex.male, label='Nữ', color='red', alpha=0.4)

# [line] So ca moi theo sex: male
# ax.plot(inc_sex.index, inc_sex.male, label='Nam', linewidth=2, color='blue')
# [line] So ca moi theo sex: female
# ax.plot(inc_sex.index, inc_sex.female, label='Nữ', linewidth=2, color='red')

# [line] BDTB so ca moi theo sex: male
ax.plot(inc_sex.index, inc_sex.case_rmean_male, label='Nam', linewidth=2, color='blue')
# [line] BDTB so ca moi theo sex: female
ax.plot(inc_sex.index, inc_sex.case_rmean_female, label='Nữ', linewidth=2, color='red')

ax.set_ylabel('Số ca mới')
ax.set_ylim([0, 7500])
ax.set_xlabel('Ngày')
ax.set_xticks(inc.index)
ax.tick_params(axis='x', labelrotation=90)
ax.set_title('Số ca mới theo ngày và biến động trung bình 7 ngày')
ax.legend(loc='upper left')
addlabels(inc.index, inc.case)

# %%
inc_adult
# Out:
#              lte18  gt18
# date_report
# 2021-05-27       7    29
# 2021-05-28       1    30
# 2021-05-29       5    38
# 2021-05-30       5    58
# 2021-05-31       0    32
# ...            ...   ...
# 2021-07-27     598  3533
# 2021-07-28     808  3844
# 2021-07-29     993  4491
# 2021-07-30     893  4153
# 2021-07-31     586  2874
#
# [66 rows x 2 columns]

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i] + 600, y[i], ha='center', va='top', rotation=90)

fig, ax = plt.subplots(figsize=(16,8))
# ax.bar(inc.index, inc.case, label='Số ca mới theo ngày', linewidth=3, color='gray')
ax.bar(inc_sex.index, inc_adult.lte18, label='<= 18', color='green', alpha=0.5)
ax.bar(inc_sex.index, inc_adult.gt18, bottom=inc_adult.lte18, label='> 18', color='yellow', alpha=0.6)
ax.plot(inc.index, inc.case_rm, label='Biến động trung bình 7 ngày', linewidth=3, color='black')
# ax.plot(inc_sex.index, inc_sex.male, label='Nam', linewidth=2, color='blue')
# ax.plot(inc_sex.index, inc_sex.female, label='Nữ', linewidth=2, color='red')
ax.set_ylabel('Số ca mới')
ax.set_ylim([0, 7500])
ax.set_xlabel('Ngày')
ax.set_xticks(inc.index)
ax.tick_params(axis='x', labelrotation=90)
ax.set_title('Số ca mới theo ngày và biến động trung bình 7 ngày')
ax.legend(loc='upper left')
addlabels(inc.index, inc.case)

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i] + 600, y[i], ha='center', va='top', rotation=90)
        
fig, ax = plt.subplots(figsize=(16,8))

# [bar] So ca moi theo ngay
ax.bar(inc.index, inc.case, label='Số ca mới theo ngày', linewidth=3, alpha=0.5, color='gray')
# [line] BDTB so ca moi theo ngay
ax.plot(inc.index, inc.case_rm, label='Biến động trung bình 7 ngày', linewidth=3, color='black')

ax.plot(inc_ag.index, inc_ag['case_rmean_inf_e16'], label='BDTB 7 ngày (inf, 16]', linewidth=2, color='red')
ax.plot(inc_ag.index, inc_ag['case_rmean_16_e44'], label='BDTB 7 ngày (16; 44]', linewidth=2, color='blue')
ax.plot(inc_ag.index, inc_ag['case_rmean_44_e65'], label='BDTB 7 ngày (44; 65]', linewidth=2, color='green')
ax.plot(inc_ag.index, inc_ag['case_rmean_65_inf'], label='BDTB 7 ngày (65; inf)', linewidth=2, color='orange')

ax.set_ylabel('Số ca mới')
ax.set_ylim([0, 7500])
ax.set_xlabel('Ngày')
ax.set_xticks(inc.index)
ax.tick_params(axis='x', labelrotation=90)
ax.set_title('Số ca mới theo ngày và biến động trung bình 7 ngày')
ax.legend(loc='upper left')
addlabels(inc.index, inc.case)

# %%
# inc_ag

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(y[i], i, y[i], ha='left', va='center')
        
data = inc_adh_cumsum[(inc_adh_cumsum.date_report == '2021-07-31') & (pd.notna(inc_adh_rollsum.addr_dist_home))].sort_values('case_cumsum')
fig, ax = plt.subplots(figsize=(12,8))
ax.barh(data.addr_dist_home.astype('str'), data.case_cumsum, color='blue', alpha=0.4)
ax.set_ylabel('Quận huyện')
ax.set_xlabel('Số ca mắc mới cộng dồn')
ax.set_title('Số ca mới cộng dồn theo quận huyện')
addlabels(data.addr_dist_home, data.case_cumsum.to_numpy())
# data.case_cumsum
# data['addr_dist_home'].unique()

# %%
data.addr_dist_home
# Out:
# 1648       HUYEN CAN GIO
# 1633      QUAN PHU NHUAN
# 1628              QUAN 9
# 1634              QUAN 2
# 1649                 NaN
# 1644        HUYEN CU CHI
# 1639              QUAN 5
# 1635              QUAN 3
# 1637             QUAN 11
# 1632        QUAN TAN PHU
# 1631       QUAN TAN BINH
# 1627        QUAN THU DUC
# 1625              QUAN 1
# 1629         QUAN GO VAP
# 1626             QUAN 12
# 1647        HUYEN NHA BE
# 1630     QUAN BINH THANH
# 1640              QUAN 6
# 1645       HUYEN HOC MON
# 1638              QUAN 4
# 1641              QUAN 8
# 1636             QUAN 10
# 1643              QUAN 7
# 1642       QUAN BINH TAN
# 1646    HUYEN BINH CHANH
# Name: addr_dist_home, dtype: object

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(y[i], i, y[i], ha='left', va='center')
        
data = inc_adh_rollsum[(inc_adh_rollsum.date_report == '2021-07-31') & (pd.notna(inc_adh_rollsum.addr_dist_home))].sort_values('case_rs')
fig, ax = plt.subplots(figsize=(12,8))
ax.barh(data.addr_dist_home.astype('str'), data.case_rs, color='blue', alpha=0.4)
ax.set_xlabel('Quận huyện')
ax.set_ylabel('Số ca mắc mới cộng dồn 14 ngày')
ax.set_title('Số ca mới cộng dồn 14 ngày theo quận huyện')

addlabels(data.addr_dist_home, data.case_rs.to_numpy())

# %%
def plot_inc_adh_rollmean(df, addr_dist):
    n = len(addr_dist)
    fig, ax = plt.subplots(1, n, figsize=(18, 4))
    fig.tight_layout()
    for i in range(n):
        data = (
                df[inc_adh_rollmean.addr_dist_home == addr_dist[i]]
                .set_index('date_report')
                .loc['2021-06-15':,:]
               )
        ax[i].bar(data.index, data.case, label='Số ca mới theo ngày', linewidth=3, color='blue', alpha=0.4)
        ax[i].plot(data.index, data.case_rm, label='Biến động trung bình 7 ngày', linewidth=3, color='black')
        ax[i].set_ylabel('Số ca mới')
        ax[i].set_ylim([0, 275])
        ax[i].set_xlabel('Ngày')
        ax[i].set_xticks(data.index)
        ax[i].set_xticklabels(data.index.strftime('%d-%m'))
        ax[i].tick_params(axis='x', labelrotation=90)
        ax[i].set_title('Số ca mới theo ngày và biến động trung bình 7 ngày ' + addr_dist[i])
        ax[i].legend()
        for k in pd.date_range('2021-06-15', '2021-07-15'):
            ax[i].text(k, data.loc[k, 'case'] + 20, data.loc[k, 'case'], ha='center', va='top', rotation=0)

# %%
# inc_adh_rollmean.loc[5, 'case']
# Out:
# 0

# %%
plot_inc_adh_rollmean(inc_adh_rollmean, ['QA01', 'QA02'])

# %%
plot_inc_adh_rollmean(inc_adh_rollmean, ['QA03', 'QA04'])

# %%
plot_inc_adh_rollmean(inc_adh_rollmean, ['QA05', 'QA06'])

# %%
plot_inc_adh_rollmean(inc_adh_rollmean, ['QA07', 'QA08'])

# %%
plot_inc_adh_rollmean(inc_adh_rollmean, ['QA09', 'QA10'])

# %%
plot_inc_adh_rollmean(inc_adh_rollmean, ['QA11', 'QA12'])

# %%
plot_inc_adh_rollmean(inc_adh_rollmean, ['QBCH', 'QBTN'])

# %%
plot_inc_adh_rollmean(inc_adh_rollmean, ['QBTH', 'QCGI'])

# %%
plot_inc_adh_rollmean(inc_adh_rollmean, ['QCCH', 'QGVP'])

# %%
plot_inc_adh_rollmean(inc_adh_rollmean, ['QHMN', 'QNBE'])

# %%
plot_inc_adh_rollmean(inc_adh_rollmean, ['QPNH', 'QTBH'])

# %%
plot_inc_adh_rollmean(inc_adh_rollmean, ['QTPH', 'QTDC'])

# %%
plot_inc_adh_rollmean(inc_adh_rollmean, ['UNKN', ''])
